# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Data

# %%
data = pd.read_csv('movies.csv')
data
# Out:
#       production_budget_usd  worldwide_gross_usd
# 0              1.000001e+05            1000000.0
# 1              1.000009e+05            1000000.0
# 2              1.000008e+05            1000045.0
# 3              5.000000e+07            1000045.0
# 4              9.000000e+07          100012499.0
# ...                     ...                  ...
# 6815           3.600000e+07           99967670.0
# 6816           1.000006e+05           99967670.1
# 6817           1.200000e+07           99967670.2
# 6818           1.800000e+07           99967670.3
# 6819           6.000000e+06           99967670.4
#
# [6820 rows x 2 columns]

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           6.820000e+03         6.820000e+03
# mean            2.461312e+07         3.356973e+07
# std             3.700131e+07         5.820972e+07
# min             6.000000e+03         7.000000e+01
# 25%             1.000005e+05         1.527108e+06
# 50%             1.100000e+07         1.220616e+07
# 75%             3.200000e+07         4.007830e+07
# max             3.000000e+08         9.366622e+08

# %% [markdown]
# ## Visualise

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data.production_budget_usd, data.worldwide_gross_usd, alpha = 0.4)
plt.xlabel('Бюджет')
plt.ylabel('Кассовый сбор')
plt.ylim(0, 900000000)
plt.xlim(0, 300000000)
# Out:
# (0.0, 300000000.0)

# %% [markdown]
# ## Model

# %%
model = LinearRegression()

# %%
X = pd.DataFrame(data.production_budget_usd)
y = pd.DataFrame(data.worldwide_gross_usd)

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[1.11928507]])

# %%
model.intercept_
# Out:
# array([6020629.59488195])

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data.production_budget_usd, data.worldwide_gross_usd, alpha = 0.4)

plt.plot(X, model.predict(X), color='red', linewidth = 3)

plt.xlabel('Бюджет')
plt.ylabel('Кассовый сбор')
plt.ylim(0, 900000000)
plt.xlim(0, 300000000)
# Out:
# (0.0, 300000000.0)

# %%
model.score(X, y)
# Out:
# 0.5062029745818803

# %%
model.predict([[20000000]])
# Out:
# array([[28406330.94346303]])
